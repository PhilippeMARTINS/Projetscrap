# %%
import pandas as pd

df = pd.read_csv('YgoM.csv')
df.head()
# Out:
#    Unnamed: 0                                     1      2     3  \
# 0           0           Ash Blossom & Joyous Spring   FIRE   3.0
# 1           1                              Maxx "C"  EARTH   2.0
# 2           2                     Accesscode Talker   DARK   NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder  LIGHT  12.0
# 4           4         Apollousa, Bow of the Goddess   WIND   NaN
#
#                              4  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                                    5                    6  \
# 0  When a card or effect is activated that includ...     ATK/ 0 DEF/ 1800
# 1  During either player's turn: You can send this...    ATK/ 500 DEF/ 200
# 2  2+ Effect Monsters\nYour opponent cannot activ...     ATK/ 2300 LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  ATK/ 3000 DEF/ 3000
# ...

# %%
#df'ATK', 'DEF' = df['6'].str.split(' ', expand=True)
df[['ATK', 'DEF']] = df['6'].str.split(' ', 1, expand=True)
df.head()
# Out:
#    Unnamed: 0                                     1      2     3  \
# 0           0           Ash Blossom & Joyous Spring   FIRE   3.0
# 1           1                              Maxx "C"  EARTH   2.0
# 2           2                     Accesscode Talker   DARK   NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder  LIGHT  12.0
# 4           4         Apollousa, Bow of the Goddess   WIND   NaN
#
#                              4  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                                    5                    6  \
# 0  When a card or effect is activated that includ...     ATK/ 0 DEF/ 1800
# 1  During either player's turn: You can send this...    ATK/ 500 DEF/ 200
# 2  2+ Effect Monsters\nYour opponent cannot activ...     ATK/ 2300 LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  ATK/ 3000 DEF/ 3000
# ...

# %%
df[['A', 'DEF']] = df['DEF'].str.split(' ', 1, expand=True)
df.head()
# Out:
#    Unnamed: 0                                     1      2     3  \
# 0           0           Ash Blossom & Joyous Spring   FIRE   3.0
# 1           1                              Maxx "C"  EARTH   2.0
# 2           2                     Accesscode Talker   DARK   NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder  LIGHT  12.0
# 4           4         Apollousa, Bow of the Goddess   WIND   NaN
#
#                              4  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                                    5                    6  \
# 0  When a card or effect is activated that includ...     ATK/ 0 DEF/ 1800
# 1  During either player's turn: You can send this...    ATK/ 500 DEF/ 200
# 2  2+ Effect Monsters\nYour opponent cannot activ...     ATK/ 2300 LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  ATK/ 3000 DEF/ 3000
# ...

# %%
df = df.drop(columns=['6', 'ATK'], axis=1)
df.head()
# Out:
#    Unnamed: 0                                     1      2     3  \
# 0           0           Ash Blossom & Joyous Spring   FIRE   3.0
# 1           1                              Maxx "C"  EARTH   2.0
# 2           2                     Accesscode Talker   DARK   NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder  LIGHT  12.0
# 4           4         Apollousa, Bow of the Goddess   WIND   NaN
#
#                              4  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                                    5            7          8  \
# 0  When a card or effect is activated that includ...  Master Pack        NaN
# 1  During either player's turn: You can send this...  Master Pack        NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  Master Pack        NaN
# ...

# %%
df = df.rename(columns={"1": "Card Name", "2": "Element", "3": "Level", "4": "Type", "5": "Description", "7": "Obtention Packs", "8": "Limitation", "9": "Img", "A": "ATK", "DEF": "D"})
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description Obtention Packs  \
# 0  When a card or effect is activated that includ...     Master Pack
# 1  During either player's turn: You can send this...     Master Pack
# 2  2+ Effect Monsters\nYour opponent cannot activ...     Master Pack
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...     Master Pack
# ...

# %%
df[['A', 'B']] = df['D'].str.split(' ', 1, expand=True)
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description Obtention Packs  \
# 0  When a card or effect is activated that includ...     Master Pack
# 1  During either player's turn: You can send this...     Master Pack
# 2  2+ Effect Monsters\nYour opponent cannot activ...     Master Pack
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...     Master Pack
# ...

# %%
df = df.rename(columns={"A": "Link", "B": "DEF"})
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description Obtention Packs  \
# 0  When a card or effect is activated that includ...     Master Pack
# 1  During either player's turn: You can send this...     Master Pack
# 2  2+ Effect Monsters\nYour opponent cannot activ...     Master Pack
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...     Master Pack
# ...

# %%
df = df.drop(columns=['D'], axis=1)
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description Obtention Packs  \
# 0  When a card or effect is activated that includ...     Master Pack
# 1  During either player's turn: You can send this...     Master Pack
# 2  2+ Effect Monsters\nYour opponent cannot activ...     Master Pack
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...     Master Pack
# ...

# %%
import numpy as np
df = df.replace('DEF/', np.nan)
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description Obtention Packs  \
# 0  When a card or effect is activated that includ...     Master Pack
# 1  During either player's turn: You can send this...     Master Pack
# 2  2+ Effect Monsters\nYour opponent cannot activ...     Master Pack
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...     Master Pack
# ...

# %%
df = df[['Unnamed: 0', 'Card Name', 'Element', 'Level', 'Type', 'Description', 'ATK', 'DEF', 'Link', 'Limitation', 'Img']]
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df.loc[df['Unnamed: 0'] == 31, 'Card Name'] = 'Tri-Brigade Bearbrumm the Rampant Rampager'
df
# Out:
#     Unnamed: 0                                     Card Name Element  Level  \
# 0            0                   Ash Blossom & Joyous Spring    FIRE    3.0
# 1            1                                      Maxx "C"   EARTH    2.0
# 2            2                             Accesscode Talker    DARK    NaN
# 3            3          Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4            4                 Apollousa, Bow of the Goddess    WIND    NaN
# 5            5                      Nibiru, the Primal Being   LIGHT   11.0
# 6            6                            Knightmare Unicorn    DARK    NaN
# 7            7                            Knightmare Phoenix    FIRE    NaN
# 8            8                                I:P Masquerena    DARK    NaN
# 9            9                          Salamangreat Almiraj    FIRE    NaN
# 10          10                          Crystron Halqifibrax   WATER    NaN
# ...

# %%
df.loc[df['Unnamed: 0'] == 31, 'Element'] = 'FIRE'
df.loc[df['Unnamed: 0'] == 31, 'Level'] = 'NaN'
df.loc[df['Unnamed: 0'] == 31, 'Type'] = '[ Beast / Link / Effect ]'
df.loc[df['Unnamed: 0'] == 31, 'ATK'] = '1700'
df.loc[df['Unnamed: 0'] == 31, 'DEF'] = np.nan
df.loc[df['Unnamed: 0'] == 31, 'Link'] = 'LINK-2'
df.loc[df['Unnamed: 0'] == 31, 'Limitation'] = 'NaN'
df.loc[df['Unnamed: 0'] == 31, 'Img'] = "['https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w50.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w100.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w140.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w200.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w260.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w360.webp','https://s3.duellinksmeta.com/cards/60c2b3aca0e24f2d54a53b74_w420.webp']"
df
# Out:
#     Unnamed: 0                                     Card Name Element Level  \
# 0            0                   Ash Blossom & Joyous Spring    FIRE   3.0
# 1            1                                      Maxx "C"   EARTH   2.0
# 2            2                             Accesscode Talker    DARK   NaN
# 3            3          Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT  12.0
# 4            4                 Apollousa, Bow of the Goddess    WIND   NaN
# 5            5                      Nibiru, the Primal Being   LIGHT  11.0
# 6            6                            Knightmare Unicorn    DARK   NaN
# 7            7                            Knightmare Phoenix    FIRE   NaN
# 8            8                                I:P Masquerena    DARK   NaN
# 9            9                          Salamangreat Almiraj    FIRE   NaN
# 10          10                          Crystron Halqifibrax   WATER   NaN
# ...

# %%
df = df.drop(columns=['Name'], axis=1)
df.head()
# Out:
#    Unnamed: 0                             Card Name Element Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE   3.0
# 1           1                              Maxx "C"   EARTH   2.0
# 2           2                     Accesscode Talker    DARK   NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT  12.0
# 4           4         Apollousa, Bow of the Goddess    WIND   NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df.replace('NaN', np.nan)
df.head()
# Out:
#    Unnamed: 0                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df.rename(columns={"Unnamed: 0": "Popularity"})
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           0           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           1                              Maxx "C"   EARTH    2.0
# 2           2                     Accesscode Talker    DARK    NaN
# 3           3  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           4         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
def add_one(x):

	return x + 1


df['Popularity'] = df['Popularity'].apply(add_one)
df
# Out:
#     Popularity                                     Card Name Element  Level  \
# 0            1                   Ash Blossom & Joyous Spring    FIRE    3.0
# 1            2                                      Maxx "C"   EARTH    2.0
# 2            3                             Accesscode Talker    DARK    NaN
# 3            4          Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4            5                 Apollousa, Bow of the Goddess    WIND    NaN
# 5            6                      Nibiru, the Primal Being   LIGHT   11.0
# 6            7                            Knightmare Unicorn    DARK    NaN
# 7            8                            Knightmare Phoenix    FIRE    NaN
# 8            9                                I:P Masquerena    DARK    NaN
# 9           10                          Salamangreat Almiraj    FIRE    NaN
# 10          11                          Crystron Halqifibrax   WATER    NaN
# ...

# %%
df.to_csv("Ygotop60Monsters.csv")

# %%
#pd.set_option('display.max_colwidth', None)
pd.reset_option('display.max_colwidth')
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 50w', 'Hold']] = df['Img'].str.split(',', 1, expand=True)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
# ...

# %%
df = df.drop(columns=['Img'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 100w', 'Img']] = df['Hold'].str.split(',', 1, expand=True)
df = df.drop(columns=['Hold'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 140w', 'Hold']] = df['Img'].str.split(',', 1, expand=True)
df = df.drop(columns=['Img'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 200w', 'Img']] = df['Hold'].str.split(',', 1, expand=True)
df = df.drop(columns=['Hold'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 260w', 'Hold']] = df['Img'].str.split(',', 1, expand=True)
df = df.drop(columns=['Img'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['Img 3600w', 'Img 420w']] = df['Hold'].str.split(',', 1, expand=True)
df = df.drop(columns=['Hold'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['A', 'B']] = df['Img 50w'].str.split('[', 1, expand=True)
#df = df.drop(columns=['Hold'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df[['C', 'D']] = df['Img 420w'].str.split(']', 1, expand=True)
#df = df.drop(columns=['Hold'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df.drop(columns=['A'], axis=1)
df = df.drop(columns=['D'], axis=1)
df = df.drop(columns=['Img 50w'], axis=1)
df = df.drop(columns=['Img 420w'], axis=1)
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df.rename(columns={"B": "Img 50w", "C": "Img 420w"})
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df.rename(columns={"Img 3600w": "Img 360w"})
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df = df[['Popularity', 'Card Name', 'Element', 'Level', 'Type', 'Description', 'ATK', 'DEF', 'Link', 'Limitation', 'Img 50w', 'Img 100w', 'Img 140w', 'Img 200w', 'Img 260w', 'Img 360w', 'Img 420w']]
df.head()
# Out:
#    Popularity                             Card Name Element  Level  \
# 0           1           Ash Blossom & Joyous Spring    FIRE    3.0
# 1           2                              Maxx "C"   EARTH    2.0
# 2           3                     Accesscode Talker    DARK    NaN
# 3           4  Divine Arsenal AA-ZEUS - Sky Thunder   LIGHT   12.0
# 4           5         Apollousa, Bow of the Goddess    WIND    NaN
#
#                           Type  \
# 0  [ Zombie / Effect / Tuner ]
# 1          [ Insect / Effect ]
# 2  [ Cyberse / Link / Effect ]
# 3   [ Machine / Xyz / Effect ]
# 4    [ Fairy / Link / Effect ]
#
#                                          Description   ATK   DEF    Link  \
# 0  When a card or effect is activated that includ...     0  1800     NaN
# 1  During either player's turn: You can send this...   500   200     NaN
# 2  2+ Effect Monsters\nYour opponent cannot activ...  2300  None  LINK–4
# 3  2 Level 12 monsters\nOnce per turn, if an Xyz ...  3000  3000     NaN
# ...

# %%
df.to_csv("Ygotop60Monsters.csv")

# %%
import re
#m = re.search('(?<=abc)def', 'abcdef')
#'(.*?[^\])'
#df['first_five_Letter']=df['Country (region)'].str.extract(r'(^w{5})')
#df['Img 50w'] = df['Img 50w'].m
df['Img 50w'] = df['Img 50w'].re.search('(?<=abc)def', 'abcdef')
df.head()

# %%
m = re.search('(?<=abc)def', df['Img 50w'])
df['Img 50w']=m
df

# %%
s=df['Img 100w']
s.str.extract(r'(?<=abc)def')
